# %% [markdown]
# ### Preprocesamiento de datos de inmigración
# Análisis inicial sobre datos demográficos de inmigrantes internacionales en España para los años 2008 - 2021.
# Fuente: Instituto Nacional de Estadística, https://www.ine.es/dynt3/inebase/index.htm?padre=3694&capsel=1963

# %%
# Importación de dependencias
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Lectura y visualización de dataset
df = pd.read_csv(
    "../1 - Inmigrantes/Datos Nacionales/24287.csv",
    encoding = "utf-8",
    delimiter = ";",
    decimal = ",",
    thousands = "."
)

df
# Out:
#               Sex        Nationality    Five-year age group  Periodo     Total
# 0      Both sexes              Total                  Total     2021  528856.0
# 1      Both sexes              Total                  Total     2020  467918.0
# 2      Both sexes              Total                  Total     2019  750480.0
# 3      Both sexes              Total                  Total     2018  643684.0
# 4      Both sexes              Total                  Total     2017  532132.0
# ...           ...                ...                    ...      ...       ...
# 59635     Females  Stateless persons  90 years old and over     2012       NaN
# 59636     Females  Stateless persons  90 years old and over     2011       NaN
# 59637     Females  Stateless persons  90 years old and over     2010       NaN
# 59638     Females  Stateless persons  90 years old and over     2009       NaN
# 59639     Females  Stateless persons  90 years old and over     2008       NaN
#
# ...

# %%
# Reemplazo de valores nulos por 0
df["Total"].replace(np.nan, 0, inplace = True)

# %%
# Conversión de float a integer al ser datos de cuenta de personas
df.Total = df.Total.astype("int")

# %%
# Comprobación de la extensión de datos por grupos de edades
df["Five-year age group"].value_counts()
# Out:
# Total                      2982
# From 0 to 4 years old      2982
# From 85 to 89 years        2982
# From 80 to 84 years        2982
# From 75 to 79 years        2982
# From 70 to 74 years        2982
# From 65 to 69 years old    2982
# From 60 to 64 years old    2982
# From 55 to 59 years old    2982
# From 50 to 54 years old    2982
# From 45 to 49 years old    2982
# From 40 to 44 years        2982
# From 35 to 39 years old    2982
# From 30 to 34 years old    2982
# From 25 to 29 years        2982
# From 20 to 24 years        2982
# From 15 to 19 years        2982
# From 10 to 14 years        2982
# From 5 to 9 years          2982
# 90 years old and over      2982
# Name: Five-year age group, dtype: int64

# %%
# Estandarización de valores para mapeo posterior
df["Five-year age group"] = df["Five-year age group"].str.strip()

# %%
mapeo = {
    "Total": "Total",
    "From 0 to 4 years old": "From 0 to 14 years old",
    "From 5 to 9 years": "From 0 to 14 years old",
    "From 10 to 14 years": "From 0 to 14 years old",
    "From 15 to 19 years": "From 15 to 29 years old",
    "From 20 to 24 years": "From 15 to 29 years old",
    "From 25 to 29 years": "From 15 to 29 years old",
    "From 30 to 34 years old": "From 30 to 44 years old",
    "From 35 to 39 years old": "From 30 to 44 years old",
    "From 40 to 44 years": "From 30 to 44 years old",
    "From 45 to 49 years old": "From 45 to 59 years old",
    "From 50 to 54 years old": "From 45 to 59 years old",
    "From 55 to 59 years old": "From 45 to 59 years old",
    "From 60 to 64 years old": "From 60 to 74 years old",
    "From 65 to 69 years old": "From 60 to 74 years old",
    "From 70 to 74 years": "From 60 to 74 years old",
    "From 75 to 79 years": "From 75 to 89 years old",
    "From 80 to 84 years": "From 75 to 89 years old",
    "From 85 to 89 years": "From 75 to 89 years old",
    "90 years old and over": "90 years old and over"
}

# %%
# Mapeo de grupos de edad de 5 años a 15 años
df['15-year age group'] = df['Five-year age group'].map(mapeo)

# %% [markdown]
# El objetivo de cambiar los grupos de edad es para coincidir con otros datasets que introducen más variables para análisis posterior

# %%
# Creación de dataframe agrupador
grouped = (
    df.groupby(['Sex', 'Nationality', '15-year age group', 'Periodo'])['Total']
    .sum()
    .reset_index()
)

grouped
# Out:
#               Sex Nationality      15-year age group  Periodo  Total
# 0      Both sexes     Algeria  90 years old and over     2008      1
# 1      Both sexes     Algeria  90 years old and over     2009      0
# 2      Both sexes     Algeria  90 years old and over     2010      0
# 3      Both sexes     Algeria  90 years old and over     2011      2
# 4      Both sexes     Algeria  90 years old and over     2012      4
# ...           ...         ...                    ...      ...    ...
# 23851       Males   Venezuela                  Total     2017  13738
# 23852       Males   Venezuela                  Total     2018  20538
# 23853       Males   Venezuela                  Total     2019  25366
# 23854       Males   Venezuela                  Total     2020  13617
# 23855       Males   Venezuela                  Total     2021  10531
#
# [23856 rows x 5 columns]

# %%
# Comprobación de sumas
sum(df.Total) - sum(grouped.Total)
# Out:
# 0

# %% [markdown]
# Análisis de la información

# %%
# Identificación de grupos de países
grupos = [
    "De Africa",
    "De América del Norte",
    "De Asia",
    "De Centro América y Caribe",
    "De Oceanía",
    "De Sudamérica",
    "Other African countries",
    "Other Asian countries",
    "Other Central American and Caribbean countries",
    "Other countries of the European Union",
    "Other European Union countries",
    "Other South American countries",
    "País de Europa menos UE27_2020",
    "País de Europa menos UE28",
    "País de la UE27_2020 sin España",
    "País de la UE28 sin España",
    "Total"
]

# %%
paises = grouped.groupby("Nationality")["Total"].sum().reset_index()

# %%
paises = paises.sort_values("Total", ascending = False)

# %%
indices = paises.loc[paises["Nationality"].isin(grupos)].index
paises.drop(indices, inplace = True)

# %%
paises.head(20)
# Out:
#            Nationality    Total
# 60            Spanish   2864686
# 36             Morocco  2269007
# 57             Romania  1859391
# 10            Colombia  1591031
# 67      United Kingdom  1124624
# 30               Italy  1096139
# 70           Venezuela  1053710
# 53                Peru   724618
# 27            Honduras   611271
# 9                China   590384
# 5               Brazil   567878
# 23              France   529010
# 20             Ecuador   516506
# 19  Dominican Republic   485748
# 25             Germany   484987
# 47            Pakistan   470411
# 1            Argentina   470100
# 48            Paraguay   443603
# 11                Cuba   414976
# 58              Russia   397040

# %%
otra_poblacion = paises.iloc[10:]['Total'].sum()
otra_fila = pd.DataFrame([['Otros', otra_poblacion]], columns=['Nationality', 'Total'])

# %%
df_new = pd.concat([paises.head(10), otra_fila], ignore_index=True)

# %%
plt.figure(figsize=(10, 7))
plt.pie(df_new['Total'], labels=df_new['Nationality'], autopct='%1.1f%%', startangle=140)
plt.title('Population Distribution with Top 10 Countries and Others Grouped')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
plt.show()
